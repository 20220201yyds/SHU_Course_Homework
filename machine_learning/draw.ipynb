# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
x = np.arange(48,960,48)
y = np.array([60,40,24,16,13,12,11,10.8,10.6,10.4,10.3,10.2,10.2,10.1,10.1,10,10.2,10.5,11])
plt.xlabel('filter_channels')
plt.ylabel('Loss')
plt.scatter([768],[10])
plt.plot(x,y)
plt.show()
